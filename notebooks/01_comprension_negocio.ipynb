# %% [markdown]
# # 01 · Comprensión del Negocio
# ### Proyecto Final — Máquina de Aprendizaje 1 | Universidad de La Sabana
# ---

# %% [markdown]
# ## 1. Contexto
#
# La seguridad vial sigue siendo un problema de salud pública a nivel mundial. La Organización Mundial de la Salud reporta que en 2021 murieron aproximadamente **1.19 millones de personas** por siniestros viales en el mundo, y que estas lesiones se encuentran entre las principales causas de muerte en población joven. En países de ingresos bajos y medianos, la carga es especialmente alta (WHO, 2023).
#
# Para el caso de India, el **Ministry of Road Transport and Highways (MoRTH)** reportó **461,312 accidentes**, **168,491 muertes** y **443,366 personas lesionadas** durante 2022. Estas cifras demuestran el interés por desarrollar herramientas tecnologicas analíticas que ayuden  amejorar la prevención, a priorizar recursos y apoyar la respuesta operativa ante accidentes automovilisticos.(MoRTH/PIB, 2023).
#
# En este proyecto se trabaja con el dataset **Indian Road Accident Dataset (2022–2025)**, que es un conjunto de datos con **20,000 registros y 24 variables** creadas del archivo de trabajo del curso.
#
# Las variables describen condiciones de los accidente, de la vía, del entorno y del momento del siniestro. A partir de esta información se busca proponer la construcción de un modelo que apoye en la clasificación de la severidad de accidentes de transito.

# %% [markdown]
# ## 2. Problema
#
# En los escenarios de accidentes de carros donde se busca una respuesta concreta e identificar patrones, tener una clasificacion temprana de este puede ayudar a complementar una asignacion inicial de recursos en cuanto problemas viales.
#
# Cuando esta clasificacion depende de una valoracion manual o preliminar de los hechos existe el riesgo de subestimar algunos casos o no saber dimensionar otros.
#
# **Pregunta de negocio:**
#
# ¿Es posible predecir si un accidente vial será **menor**, **mayor** o **fatal** a partir de las condiciones observadas en el entorno, la vía y el momento del siniestro. De manera que el resultado sirva como apoyo inicial para identificar una mejora vial?
#
# **Alcance realista del proyecto:**
#
# El modelo **no reemplaza** la decisión humana ni el protocolo de atención; su propósito es **apoyar** la mejora vial y distribucion de los recursos viales con base en patrones históricos del dataset.

# %% [markdown]
# ## 3. Objetivo general
#
# Construir modelos supervisados de clasificación multiclase que predigan la variable `accident_severity` (**menor / mayor / fatal**) a partir de variables contextuales del accidente, con el fin de aportar evidencia para análisis de seguridad vial.

# %% [markdown]
# ## 4. Objetivos específicos
#
# 1. Realizar un análisis exploratorio del dataset para comprender la distribución de los datos, su calidad y las relaciones entre variables relevantes para la severidad de accidentes.
#
# 2. Preparar los datos mediante procesos de limpieza, imputación y transformación, asegurando su calidad para el modelado.
#
# 3. Aplicar feature engineering basado en condiciones relevantes de seguridad vial, como conducción nocturna, clima, visibilidad e interacciones entre variables.
#
# 4. Entrenar y comparar modelos de clasificación (Árbol de Decisión, Random Forest y Gradient Boosting) utilizando validación cruzada estratificada y ajuste de hiperparámetros.
#
# 5. Evaluar el desempeño de los modelos mediante métricas adecuadas para problemas multiclase con desbalance y comunicar los resultados a través de notebooks y una aplicación en Streamlit.

# %% [markdown]
# ## 5. Enfoque metodológico: CRISP-DM
#
# El proyecto se organiza con la lógica de **CRISP-DM** (*Cross-Industry Standard Process for Data Mining*), planteada en 6 fases iterativas:
#
# | Fase | Recurso del proyecto | Contenido principal |
# |------|----------------------|---------------------|
# | **1. Business Understanding** | `01_comprension_negocio.ipynb` | Contexto, problema, objetivos y criterio de éxito |
# | **2. Data Understanding** | `02_comprension_datos.ipynb` | Exploración inicial, calidad de datos y hallazgos descriptivos |
# | **3. Data Preparation** | `03_preparacion_datos.ipynb` | Limpieza, imputación, codificación y preparación para modelado |
# | **4. Modeling** | `04_modelado.ipynb` | Entrenamiento y ajuste de Árbol, Random Forest y Gradient Boosting |
# | **5. Evaluation** | `05_evaluacion.ipynb` | Comparación de métricas, reportes de clasificación e interpretación |
# | **6. Deployment / Comunicación / Conclusiones** | App en **Streamlit** + conclusiones | Visualización de resultados y cierre del proyecto |

# %% [markdown]
# ## 6. Variable objetivo y criterio de éxito del negocio
#
# **Variable objetivo:** `accident_severity` — tres clases:
#
# | Clase | Descripción | Prioridad operativa |
# |-------|-------------|---------------------|
# | `minor` | Daños materiales o lesiones leves | Baja |
# | `major` | Lesiones graves o daños considerables | Media |
# | `fatal` | Víctimas mortales | **Alta** |
#
# **Implicaciones de errores del modelo:**
#
# | Error | Qué ocurre | Consecuencia |
# |-------|-----------|---------------|
# | **Falso Negativo (fatal)** | El modelo no detecta un accidente fatal | No tener suficientes pruebas de que en un entorno vial existe un riesgo importante para la mejora de este |
# | **Falso Positivo (fatal)** | El modelo clasifica como fatal un accidente menor | Uso innecesario de recursos viales |
#
# La clase `fatal` tiene la mayor prioridad operativa. El modelo debe maximizar el **Recall de la clase fatal**.

# %% [markdown]
# ## 7. Modelos implementados
#
# | Modelo | Justificación |
# |--------|---------------|
# | **Árbol de Decisión** | Ofrece reglas más interpretables y facilita explicar por qué un caso cae en una clase determinada. |
# | **Random Forest** | Reduce la varianza del árbol individual mediante un ensamble de múltiples árboles, mejorando estabilidad. |
# | **Gradient Boosting** | Aprende secuencialmente de los errores previos y puede capturar patrones complejos incluso cuando la señal en los datos es limitada. |
#
# Los tres se optimizan con **GridSearchCV + validación cruzada estratificada (5-fold)**, scoring=`f1_weighted`.

# %% [markdown]
# ## 8. Criterio de éxito técnico y referencias
#
# ### Criterio de éxito técnico
#
# | Métrica | Umbral propuesto | Justificación |
# |---------|------------------|---------------|
# | Accuracy | ≥ 0.55 | Debe superar claramente al baseline de clase más frecuente |
# | F1 ponderado | ≥ 0.50 | Resume el equilibrio entre precisión y recall considerando el desbalance |
# | Recall ponderado | ≥ 0.55 | Ayuda a verificar sensibilidad global del sistema |
# | Análisis por clase | Obligatorio | Evita depender solo de promedios y obliga a revisar el comportamiento de `minor`, `major` y `fatal` |
#
# ### Referencias sugeridas
#
# - **WHO.** (2023). *Global status report on road safety 2023*. World Health Organization. https://www.who.int/teams/social-determinants-of-health/safety-and-mobility/global-status-report-on-road-safety-2023
# - **MoRTH / Press Information Bureau (PIB).** (2023, 31 de octubre). *Ministry of Road Transport and Highways releases Annual Report on Road Accidents in India – 2022*. https://www.pib.gov.in/PressReleaseIframePage.aspx?PRID=1973295
# - **IBM.** (s. f.). *CRISP-DM in IBM SPSS Modeler*. https://www.ibm.com/docs/en/spss-modeler/18.6.0?topic=overview-crisp-dm-in-spss-modeler
# - **scikit-learn.** (2025a). *GridSearchCV*. https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
# - **scikit-learn.** (2025b). *StratifiedKFold*. https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html
# - **scikit-learn.** (2025c). *classification_report*. https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html
# - **scikit-learn.** (2025d). *f1_score*. https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html
# - **Fountas, G., Fonzone, A., Kelly, J., & Yannis, G.** (2020). *The joint effect of weather and lighting conditions on injury severities of single-vehicle accidents*. Journal of Safety Research. https://www.sciencedirect.com/science/article/abs/pii/S2213665720300142
# - **Ghasemzadeh, A., Ahmed, M. M., & others.** (2019). *Exploring factors contributing to injury severity at work zones in Washington State*. Accident Analysis & Prevention / IATSS Research. https://www.sciencedirect.com/science/article/pii/S038611121830044X
